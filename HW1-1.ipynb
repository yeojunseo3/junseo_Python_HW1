# %%
def add_data(friend) :
    
    katok.append(None)
    kLen = len(katok)
    katok[kLen-1] = friend
    

def insert_data(position, friend) :
    if position < 0 or position > len(katok) :
        print("데이터를 삽입할 범위를 벗어났습니다.")
        return
    
    katok.append(None)
    kLen = len(katok)
    
    for i in range(kLen-1, position, -1) :
        katok[i] = katok[i-1]
        katok[i-1] = None
    
    katok[position] = friend
    
def delete_data(position) :
    if position < 0 or position > len(katok) :
        print("데이터를 삭제할 범위를 벗어났습니다.")
        return
    
    kLen = len(katok)
    katok[position] = None
    
    for i in range(position +1,kLen) :
        katok[i-1] = katok[i]
        katok[i] = None
    del(katok[kLen-1])
    
    
katok = []
select = -1

if __name__ =="__main__" :
    
    while(select != 3):
        
        select = int(input("선택하시오(1: 추가, 2: 삭제, 3: 종료)-->"))
        
        if (select == 1) :
            data = input("추가할 데이터-->")
            def find_and_insert_data(friend, k_count) :
                findPos = -1
                for i in range(len(katok)) :
                    pair = katok[i]
                    print(katok)
                if k_count >= pair[1] :
                    findPos = i
                    print(katok)
                if findPos == -1:
                    findPos = len(katok)
                    insert_data(findPos,(friend,k_count))
                    print(katok)
                    
                
        elif (select == 2) :
            pos = int(input("삭제할 위치-->"))
            delete_data(pos)
            print(katok)
            
        elif (select == 3) :
            print(katok)
            exit
        
        else :
            print("1~3 중 하나를 입력하시오.")
            continue
# Out:
# 선택하시오(1: 추가, 2: 삭제, 3: 종료)-->1
# 추가할 데이터-->('다현',200)
# 선택하시오(1: 추가, 2: 삭제, 3: 종료)-->1
# 추가할 데이터-->('정연',150)
# 선택하시오(1: 추가, 2: 삭제, 3: 종료)-->1
# 추가할 데이터-->('모모',170)
# 선택하시오(1: 추가, 2: 삭제, 3: 종료)-->2
# 삭제할 위치-->2
# 데이터를 삭제할 범위를 벗어났습니다.
# []
# 선택하시오(1: 추가, 2: 삭제, 3: 종료)-->2
# 삭제할 위치-->2
# 데이터를 삭제할 범위를 벗어났습니다.
# []
# 선택하시오(1: 추가, 2: 삭제, 3: 종료)-->3
# []
